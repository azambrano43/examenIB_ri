# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import gensim.downloader as api
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
import string

# %%
nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ### 1. Carga y limpieza inicial del corpus
#
# Vamos a cargar nuestros archivos de 'tomatoes_reviews' en DataFrames de pandas, con el fin de poder manipularlos de una manera mucho más fácil y eficaz.

# %%
df_tomatoes_critics = pd.read_csv("tomatoes_data/rotten_tomatoes_critic_reviews.csv")
df_tomatoes_movies = pd.read_csv("tomatoes_data/rotten_tomatoes_movies.csv")

# %%
df_tomatoes_movies["rotten_tomatoes_link"] = df_tomatoes_movies["rotten_tomatoes_link"].astype("string")
df_tomatoes_movies["movie_title"] = df_tomatoes_movies["movie_title"].astype("string")

# %% [markdown]
# ### 2. Preprocesamiento del corpus
#
# Nuestro corpus está contenido en el archivo 'rotten_tomatoes_critic_reviews.csv' específicamente en la columna 'review_content'. Ahora lo que vamos a realizar es el preprocesamiento de este corpus, para ello vamos a realizar el siguiente proceso:
#
# 1. Extracción de contenido relevante de los documentos
# 2. Eliminar caracteres no deseados y normalizar el texto
# 3. Tokenización del texto
# 4. Eliminación de stop words y aplicación de lematización
#
# Para este apartado vamos a crear una sola función de nombre preprocesar_contenido, la cual va a realizar todo el proceso de tokenización y normalización de cada contenido de cada documento que conforma el corpus

# %%
# Configuración de lematizador y stopwords
lemmatizer = WordNetLemmatizer()

# Carga de stopwords en inglés y signos de puntuación para limpiar
stopwords = set(stopwords.words('english'))
signos_puntuacion = string.punctuation

# %%
# Función de preprocesamiento (sin etiquetado POS)
def preprocesar_contenido(contenido):
    # Convertir texto a minúsculas
    contenido = contenido.lower()

    # Eliminar caracteres redundantes y limpiar texto
    contenido = re.sub(r'\d+', '', contenido)  # Eliminar números
    contenido = re.sub(r'\s+', ' ', contenido)  # Eliminar saltos de línea y espacios redundantes

    # Remover signos de puntuación
    contenido = contenido.translate(str.maketrans("", "", signos_puntuacion))

    # Tokenización
    contenido_tokenizado = word_tokenize(contenido)

    # Eliminar stopwords
    tokens_sin_stopwords = [word for word in contenido_tokenizado if word not in stopwords]

    # Lematización asumiendo sustantivos por defecto
    tokens_lematizados = [lemmatizer.lemmatize(token, wordnet.NOUN) for token in tokens_sin_stopwords]

    # Reconstruir texto lematizado a un solo string
    contenido_lematizado_str = " ".join(tokens_lematizados)

    return contenido_lematizado_str

# %%
# Conversión entre tipo de datos para evitar problemas
df_tomatoes_critics
df_tomatoes_critics["review_content"] = df_tomatoes_critics["review_content"].astype("string")
df_tomatoes_critics = df_tomatoes_critics.dropna(subset=["review_content"])

# %%
# Preprocesar todo el corpus
for index, row in df_tomatoes_critics.iterrows():
    print(f"Iterando sobre elemento {index+1} del .csv de los corpus")
    df_tomatoes_critics.at[index, "contenido_preproc_str"] = preprocesar_contenido(row["review_content"])
# Out:
# Streaming output truncated to the last 5000 lines.
# Iterando sobre elemento 1124829 del .csv de los corpus
# Iterando sobre elemento 1124830 del .csv de los corpus
# Iterando sobre elemento 1124831 del .csv de los corpus
# Iterando sobre elemento 1124832 del .csv de los corpus
# Iterando sobre elemento 1124834 del .csv de los corpus
# Iterando sobre elemento 1124835 del .csv de los corpus
# Iterando sobre elemento 1124836 del .csv de los corpus
# Iterando sobre elemento 1124837 del .csv de los corpus
# Iterando sobre elemento 1124838 del .csv de los corpus
# Iterando sobre elemento 1124839 del .csv de los corpus
# Iterando sobre elemento 1124840 del .csv de los corpus
# Iterando sobre elemento 1124841 del .csv de los corpus
# Iterando sobre elemento 1124842 del .csv de los corpus
# Iterando sobre elemento 1124843 del .csv de los corpus
# Iterando sobre elemento 1124844 del .csv de los corpus
# Iterando sobre elemento 1124845 del .csv de los corpus
# Iterando sobre elemento 1124846 del .csv de los corpus
# Iterando sobre elemento 1124847 del .csv de los corpus
# Iterando sobre elemento 1124848 del .csv de los corpus
# Iterando sobre elemento 1124849 del .csv de los corpus
# Iterando sobre elemento 1124850 del .csv de los corpus
# Iterando sobre elemento 1124852 del .csv de los corpus
# Iterando sobre elemento 1124853 del .csv de los corpus
# Iterando sobre elemento 1124854 del .csv de los corpus
# Iterando sobre elemento 1124855 del .csv de los corpus
# Iterando sobre elemento 1124856 del .csv de los corpus
# Iterando sobre elemento 1124857 del .csv de los corpus
# Iterando sobre elemento 1124858 del .csv de los corpus
# Iterando sobre elemento 1124859 del .csv de los corpus
# Iterando sobre elemento 1124860 del .csv de los corpus
# Iterando sobre elemento 1124863 del .csv de los corpus
# Iterando sobre elemento 1124864 del .csv de los corpus
# Iterando sobre elemento 1124866 del .csv de los corpus
# Iterando sobre elemento 1124869 del .csv de los corpus
# Iterando sobre elemento 1124870 del .csv de los corpus
# Iterando sobre elemento 1124876 del .csv de los corpus
# Iterando sobre elemento 1124877 del .csv de los corpus
# Iterando sobre elemento 1124879 del .csv de los corpus
# Iterando sobre elemento 1124882 del .csv de los corpus
# Iterando sobre elemento 1124883 del .csv de los corpus
# Iterando sobre elemento 1124884 del .csv de los corpus
# Iterando sobre elemento 1124885 del .csv de los corpus
# Iterando sobre elemento 1124887 del .csv de los corpus
# Iterando sobre elemento 1124888 del .csv de los corpus
# Iterando sobre elemento 1124889 del .csv de los corpus
# Iterando sobre elemento 1124890 del .csv de los corpus
# Iterando sobre elemento 1124891 del .csv de los corpus
# Iterando sobre elemento 1124892 del .csv de los corpus
# Iterando sobre elemento 1124893 del .csv de los corpus
# Iterando sobre elemento 1124894 del .csv de los corpus
# Iterando sobre elemento 1124895 del .csv de los corpus
# Iterando sobre elemento 1124896 del .csv de los corpus
# Iterando sobre elemento 1124897 del .csv de los corpus
# Iterando sobre elemento 1124898 del .csv de los corpus
# Iterando sobre elemento 1124899 del .csv de los corpus
# Iterando sobre elemento 1124900 del .csv de los corpus
# Iterando sobre elemento 1124901 del .csv de los corpus
# Iterando sobre elemento 1124902 del .csv de los corpus
# Iterando sobre elemento 1124903 del .csv de los corpus
# Iterando sobre elemento 1124904 del .csv de los corpus
# Iterando sobre elemento 1124905 del .csv de los corpus
# Iterando sobre elemento 1124906 del .csv de los corpus
# Iterando sobre elemento 1124907 del .csv de los corpus
# Iterando sobre elemento 1124908 del .csv de los corpus
# Iterando sobre elemento 1124909 del .csv de los corpus
# Iterando sobre elemento 1124910 del .csv de los corpus
# Iterando sobre elemento 1124911 del .csv de los corpus
# Iterando sobre elemento 1124912 del .csv de los corpus
# Iterando sobre elemento 1124913 del .csv de los corpus
# Iterando sobre elemento 1124914 del .csv de los corpus
# Iterando sobre elemento 1124915 del .csv de los corpus
# Iterando sobre elemento 1124916 del .csv de los corpus
# Iterando sobre elemento 1124919 del .csv de los corpus
# Iterando sobre elemento 1124920 del .csv de los corpus
# Iterando sobre elemento 1124921 del .csv de los corpus
# Iterando sobre elemento 1124922 del .csv de los corpus
# Iterando sobre elemento 1124923 del .csv de los corpus
# Iterando sobre elemento 1124928 del .csv de los corpus
# Iterando sobre elemento 1124930 del .csv de los corpus
# Iterando sobre elemento 1124934 del .csv de los corpus
# Iterando sobre elemento 1124935 del .csv de los corpus
# Iterando sobre elemento 1124936 del .csv de los corpus
# Iterando sobre elemento 1124937 del .csv de los corpus
# Iterando sobre elemento 1124938 del .csv de los corpus
# Iterando sobre elemento 1124939 del .csv de los corpus
# Iterando sobre elemento 1124940 del .csv de los corpus
# Iterando sobre elemento 1124941 del .csv de los corpus
# Iterando sobre elemento 1124942 del .csv de los corpus
# Iterando sobre elemento 1124943 del .csv de los corpus
# Iterando sobre elemento 1124944 del .csv de los corpus
# Iterando sobre elemento 1124945 del .csv de los corpus
# Iterando sobre elemento 1124946 del .csv de los corpus
# Iterando sobre elemento 1124947 del .csv de los corpus
# Iterando sobre elemento 1124948 del .csv de los corpus
# Iterando sobre elemento 1124949 del .csv de los corpus
# Iterando sobre elemento 1124950 del .csv de los corpus
# Iterando sobre elemento 1124951 del .csv de los corpus
# Iterando sobre elemento 1124953 del .csv de los corpus
# Iterando sobre elemento 1124955 del .csv de los corpus
# Iterando sobre elemento 1124956 del .csv de los corpus
# Iterando sobre elemento 1124959 del .csv de los corpus
# Iterando sobre elemento 1124966 del .csv de los corpus
# Iterando sobre elemento 1124967 del .csv de los corpus
# Iterando sobre elemento 1124971 del .csv de los corpus
# Iterando sobre elemento 1124972 del .csv de los corpus
# Iterando sobre elemento 1124973 del .csv de los corpus
# Iterando sobre elemento 1124974 del .csv de los corpus
# Iterando sobre elemento 1124975 del .csv de los corpus
# Iterando sobre elemento 1124976 del .csv de los corpus
# Iterando sobre elemento 1124977 del .csv de los corpus
# Iterando sobre elemento 1124978 del .csv de los corpus
# Iterando sobre elemento 1124979 del .csv de los corpus
# Iterando sobre elemento 1124981 del .csv de los corpus
# Iterando sobre elemento 1124982 del .csv de los corpus
# Iterando sobre elemento 1124983 del .csv de los corpus
# Iterando sobre elemento 1124984 del .csv de los corpus
# Iterando sobre elemento 1124986 del .csv de los corpus
# Iterando sobre elemento 1124990 del .csv de los corpus
# Iterando sobre elemento 1124991 del .csv de los corpus
# Iterando sobre elemento 1124992 del .csv de los corpus
# Iterando sobre elemento 1124993 del .csv de los corpus
# Iterando sobre elemento 1124994 del .csv de los corpus
# Iterando sobre elemento 1124995 del .csv de los corpus
# Iterando sobre elemento 1124996 del .csv de los corpus
# Iterando sobre elemento 1124997 del .csv de los corpus
# Iterando sobre elemento 1124998 del .csv de los corpus
# Iterando sobre elemento 1124999 del .csv de los corpus
# Iterando sobre elemento 1125000 del .csv de los corpus
# Iterando sobre elemento 1125001 del .csv de los corpus
# Iterando sobre elemento 1125002 del .csv de los corpus
# Iterando sobre elemento 1125003 del .csv de los corpus
# Iterando sobre elemento 1125004 del .csv de los corpus
# Iterando sobre elemento 1125005 del .csv de los corpus
# Iterando sobre elemento 1125006 del .csv de los corpus
# Iterando sobre elemento 1125007 del .csv de los corpus
# Iterando sobre elemento 1125008 del .csv de los corpus
# Iterando sobre elemento 1125009 del .csv de los corpus
# Iterando sobre elemento 1125010 del .csv de los corpus
# Iterando sobre elemento 1125011 del .csv de los corpus
# Iterando sobre elemento 1125012 del .csv de los corpus
# Iterando sobre elemento 1125013 del .csv de los corpus
# Iterando sobre elemento 1125014 del .csv de los corpus
# Iterando sobre elemento 1125015 del .csv de los corpus
# Iterando sobre elemento 1125016 del .csv de los corpus
# Iterando sobre elemento 1125017 del .csv de los corpus
# Iterando sobre elemento 1125018 del .csv de los corpus
# Iterando sobre elemento 1125019 del .csv de los corpus
# Iterando sobre elemento 1125020 del .csv de los corpus
# Iterando sobre elemento 1125021 del .csv de los corpus
# Iterando sobre elemento 1125022 del .csv de los corpus
# Iterando sobre elemento 1125023 del .csv de los corpus
# Iterando sobre elemento 1125024 del .csv de los corpus
# Iterando sobre elemento 1125025 del .csv de los corpus
# Iterando sobre elemento 1125026 del .csv de los corpus
# Iterando sobre elemento 1125027 del .csv de los corpus
# Iterando sobre elemento 1125028 del .csv de los corpus
# Iterando sobre elemento 1125029 del .csv de los corpus
# Iterando sobre elemento 1125030 del .csv de los corpus
# Iterando sobre elemento 1125031 del .csv de los corpus
# Iterando sobre elemento 1125032 del .csv de los corpus
# Iterando sobre elemento 1125033 del .csv de los corpus
# Iterando sobre elemento 1125034 del .csv de los corpus
# Iterando sobre elemento 1125035 del .csv de los corpus
# Iterando sobre elemento 1125036 del .csv de los corpus
# Iterando sobre elemento 1125037 del .csv de los corpus
# Iterando sobre elemento 1125042 del .csv de los corpus
# Iterando sobre elemento 1125043 del .csv de los corpus
# Iterando sobre elemento 1125044 del .csv de los corpus
# Iterando sobre elemento 1125046 del .csv de los corpus
# Iterando sobre elemento 1125050 del .csv de los corpus
# Iterando sobre elemento 1125054 del .csv de los corpus
# Iterando sobre elemento 1125055 del .csv de los corpus
# Iterando sobre elemento 1125057 del .csv de los corpus
# Iterando sobre elemento 1125058 del .csv de los corpus
# Iterando sobre elemento 1125059 del .csv de los corpus
# Iterando sobre elemento 1125060 del .csv de los corpus
# Iterando sobre elemento 1125061 del .csv de los corpus
# Iterando sobre elemento 1125063 del .csv de los corpus
# Iterando sobre elemento 1125064 del .csv de los corpus
# Iterando sobre elemento 1125065 del .csv de los corpus
# Iterando sobre elemento 1125066 del .csv de los corpus
# Iterando sobre elemento 1125067 del .csv de los corpus
# Iterando sobre elemento 1125068 del .csv de los corpus
# Iterando sobre elemento 1125069 del .csv de los corpus
# Iterando sobre elemento 1125070 del .csv de los corpus
# Iterando sobre elemento 1125071 del .csv de los corpus
# Iterando sobre elemento 1125072 del .csv de los corpus
# Iterando sobre elemento 1125073 del .csv de los corpus
# Iterando sobre elemento 1125074 del .csv de los corpus
# Iterando sobre elemento 1125075 del .csv de los corpus
# Iterando sobre elemento 1125076 del .csv de los corpus
# Iterando sobre elemento 1125077 del .csv de los corpus
# Iterando sobre elemento 1125078 del .csv de los corpus
# Iterando sobre elemento 1125079 del .csv de los corpus
# Iterando sobre elemento 1125080 del .csv de los corpus
# Iterando sobre elemento 1125081 del .csv de los corpus
# Iterando sobre elemento 1125082 del .csv de los corpus
# Iterando sobre elemento 1125083 del .csv de los corpus
# Iterando sobre elemento 1125084 del .csv de los corpus
# Iterando sobre elemento 1125085 del .csv de los corpus
# Iterando sobre elemento 1125086 del .csv de los corpus
# Iterando sobre elemento 1125087 del .csv de los corpus
# Iterando sobre elemento 1125088 del .csv de los corpus
# Iterando sobre elemento 1125089 del .csv de los corpus
# Iterando sobre elemento 1125090 del .csv de los corpus
# Iterando sobre elemento 1125091 del .csv de los corpus
# Iterando sobre elemento 1125092 del .csv de los corpus
# Iterando sobre elemento 1125093 del .csv de los corpus
# Iterando sobre elemento 1125094 del .csv de los corpus
# Iterando sobre elemento 1125095 del .csv de los corpus
# Iterando sobre elemento 1125096 del .csv de los corpus
# Iterando sobre elemento 1125097 del .csv de los corpus
# Iterando sobre elemento 1125098 del .csv de los corpus
# Iterando sobre elemento 1125099 del .csv de los corpus
# Iterando sobre elemento 1125100 del .csv de los corpus
# Iterando sobre elemento 1125101 del .csv de los corpus
# Iterando sobre elemento 1125102 del .csv de los corpus
# Iterando sobre elemento 1125103 del .csv de los corpus
# Iterando sobre elemento 1125104 del .csv de los corpus
# Iterando sobre elemento 1125105 del .csv de los corpus
# Iterando sobre elemento 1125106 del .csv de los corpus
# Iterando sobre elemento 1125107 del .csv de los corpus
# Iterando sobre elemento 1125108 del .csv de los corpus
# Iterando sobre elemento 1125109 del .csv de los corpus
# Iterando sobre elemento 1125110 del .csv de los corpus
# Iterando sobre elemento 1125111 del .csv de los corpus
# Iterando sobre elemento 1125112 del .csv de los corpus
# Iterando sobre elemento 1125113 del .csv de los corpus
# Iterando sobre elemento 1125114 del .csv de los corpus
# Iterando sobre elemento 1125115 del .csv de los corpus
# Iterando sobre elemento 1125116 del .csv de los corpus
# Iterando sobre elemento 1125117 del .csv de los corpus
# Iterando sobre elemento 1125118 del .csv de los corpus
# Iterando sobre elemento 1125119 del .csv de los corpus
# Iterando sobre elemento 1125120 del .csv de los corpus
# Iterando sobre elemento 1125121 del .csv de los corpus
# Iterando sobre elemento 1125122 del .csv de los corpus
# Iterando sobre elemento 1125123 del .csv de los corpus
# Iterando sobre elemento 1125124 del .csv de los corpus
# Iterando sobre elemento 1125125 del .csv de los corpus
# Iterando sobre elemento 1125126 del .csv de los corpus
# Iterando sobre elemento 1125127 del .csv de los corpus
# Iterando sobre elemento 1125128 del .csv de los corpus
# Iterando sobre elemento 1125129 del .csv de los corpus
# Iterando sobre elemento 1125130 del .csv de los corpus
# Iterando sobre elemento 1125131 del .csv de los corpus
# Iterando sobre elemento 1125132 del .csv de los corpus
# Iterando sobre elemento 1125133 del .csv de los corpus
# Iterando sobre elemento 1125134 del .csv de los corpus
# Iterando sobre elemento 1125135 del .csv de los corpus
# Iterando sobre elemento 1125136 del .csv de los corpus
# Iterando sobre elemento 1125137 del .csv de los corpus
# Iterando sobre elemento 1125138 del .csv de los corpus
# Iterando sobre elemento 1125139 del .csv de los corpus
# Iterando sobre elemento 1125140 del .csv de los corpus
# Iterando sobre elemento 1125141 del .csv de los corpus
# Iterando sobre elemento 1125142 del .csv de los corpus
# Iterando sobre elemento 1125143 del .csv de los corpus
# Iterando sobre elemento 1125144 del .csv de los corpus
# Iterando sobre elemento 1125145 del .csv de los corpus
# Iterando sobre elemento 1125146 del .csv de los corpus
# Iterando sobre elemento 1125147 del .csv de los corpus
# Iterando sobre elemento 1125148 del .csv de los corpus
# Iterando sobre elemento 1125150 del .csv de los corpus
# Iterando sobre elemento 1125155 del .csv de los corpus
# Iterando sobre elemento 1125156 del .csv de los corpus
# Iterando sobre elemento 1125157 del .csv de los corpus
# Iterando sobre elemento 1125158 del .csv de los corpus
# Iterando sobre elemento 1125159 del .csv de los corpus
# Iterando sobre elemento 1125160 del .csv de los corpus
# Iterando sobre elemento 1125161 del .csv de los corpus
# Iterando sobre elemento 1125162 del .csv de los corpus
# Iterando sobre elemento 1125163 del .csv de los corpus
# Iterando sobre elemento 1125164 del .csv de los corpus
# Iterando sobre elemento 1125165 del .csv de los corpus
# Iterando sobre elemento 1125166 del .csv de los corpus
# Iterando sobre elemento 1125167 del .csv de los corpus
# Iterando sobre elemento 1125168 del .csv de los corpus
# Iterando sobre elemento 1125169 del .csv de los corpus
# Iterando sobre elemento 1125170 del .csv de los corpus
# Iterando sobre elemento 1125171 del .csv de los corpus
# Iterando sobre elemento 1125172 del .csv de los corpus
# Iterando sobre elemento 1125173 del .csv de los corpus
# Iterando sobre elemento 1125174 del .csv de los corpus
# Iterando sobre elemento 1125175 del .csv de los corpus
# Iterando sobre elemento 1125176 del .csv de los corpus
# Iterando sobre elemento 1125177 del .csv de los corpus
# Iterando sobre elemento 1125178 del .csv de los corpus
# Iterando sobre elemento 1125179 del .csv de los corpus
# Iterando sobre elemento 1125180 del .csv de los corpus
# Iterando sobre elemento 1125181 del .csv de los corpus
# Iterando sobre elemento 1125182 del .csv de los corpus
# Iterando sobre elemento 1125183 del .csv de los corpus
# Iterando sobre elemento 1125184 del .csv de los corpus
# Iterando sobre elemento 1125185 del .csv de los corpus
# Iterando sobre elemento 1125186 del .csv de los corpus
# Iterando sobre elemento 1125187 del .csv de los corpus
# Iterando sobre elemento 1125188 del .csv de los corpus
# Iterando sobre elemento 1125189 del .csv de los corpus
# Iterando sobre elemento 1125190 del .csv de los corpus
# Iterando sobre elemento 1125191 del .csv de los corpus
# Iterando sobre elemento 1125192 del .csv de los corpus
# Iterando sobre elemento 1125193 del .csv de los corpus
# Iterando sobre elemento 1125194 del .csv de los corpus
# Iterando sobre elemento 1125195 del .csv de los corpus
# Iterando sobre elemento 1125196 del .csv de los corpus
# Iterando sobre elemento 1125197 del .csv de los corpus
# Iterando sobre elemento 1125198 del .csv de los corpus
# Iterando sobre elemento 1125199 del .csv de los corpus
# Iterando sobre elemento 1125200 del .csv de los corpus
# Iterando sobre elemento 1125201 del .csv de los corpus
# Iterando sobre elemento 1125202 del .csv de los corpus
# Iterando sobre elemento 1125203 del .csv de los corpus
# Iterando sobre elemento 1125204 del .csv de los corpus
# Iterando sobre elemento 1125205 del .csv de los corpus
# Iterando sobre elemento 1125206 del .csv de los corpus
# Iterando sobre elemento 1125207 del .csv de los corpus
# Iterando sobre elemento 1125208 del .csv de los corpus
# Iterando sobre elemento 1125209 del .csv de los corpus
# Iterando sobre elemento 1125210 del .csv de los corpus
# Iterando sobre elemento 1125211 del .csv de los corpus
# Iterando sobre elemento 1125212 del .csv de los corpus
# Iterando sobre elemento 1125213 del .csv de los corpus
# Iterando sobre elemento 1125216 del .csv de los corpus
# Iterando sobre elemento 1125217 del .csv de los corpus
# Iterando sobre elemento 1125218 del .csv de los corpus
# Iterando sobre elemento 1125219 del .csv de los corpus
# Iterando sobre elemento 1125220 del .csv de los corpus
# Iterando sobre elemento 1125221 del .csv de los corpus
# Iterando sobre elemento 1125222 del .csv de los corpus
# Iterando sobre elemento 1125223 del .csv de los corpus
# Iterando sobre elemento 1125224 del .csv de los corpus
# Iterando sobre elemento 1125225 del .csv de los corpus
# Iterando sobre elemento 1125226 del .csv de los corpus
# Iterando sobre elemento 1125227 del .csv de los corpus
# Iterando sobre elemento 1125228 del .csv de los corpus
# Iterando sobre elemento 1125229 del .csv de los corpus
# Iterando sobre elemento 1125230 del .csv de los corpus
# Iterando sobre elemento 1125231 del .csv de los corpus
# Iterando sobre elemento 1125232 del .csv de los corpus
# Iterando sobre elemento 1125233 del .csv de los corpus
# Iterando sobre elemento 1125234 del .csv de los corpus
# Iterando sobre elemento 1125235 del .csv de los corpus
# Iterando sobre elemento 1125236 del .csv de los corpus
# Iterando sobre elemento 1125237 del .csv de los corpus
# Iterando sobre elemento 1125238 del .csv de los corpus
# Iterando sobre elemento 1125239 del .csv de los corpus
# Iterando sobre elemento 1125240 del .csv de los corpus
# Iterando sobre elemento 1125241 del .csv de los corpus
# Iterando sobre elemento 1125242 del .csv de los corpus
# Iterando sobre elemento 1125243 del .csv de los corpus
# Iterando sobre elemento 1125244 del .csv de los corpus
# Iterando sobre elemento 1125245 del .csv de los corpus
# Iterando sobre elemento 1125246 del .csv de los corpus
# Iterando sobre elemento 1125247 del .csv de los corpus
# Iterando sobre elemento 1125248 del .csv de los corpus
# Iterando sobre elemento 1125249 del .csv de los corpus
# Iterando sobre elemento 1125250 del .csv de los corpus
# Iterando sobre elemento 1125251 del .csv de los corpus
# Iterando sobre elemento 1125252 del .csv de los corpus
# Iterando sobre elemento 1125253 del .csv de los corpus
# Iterando sobre elemento 1125254 del .csv de los corpus
# Iterando sobre elemento 1125255 del .csv de los corpus
# Iterando sobre elemento 1125256 del .csv de los corpus
# Iterando sobre elemento 1125257 del .csv de los corpus
# Iterando sobre elemento 1125258 del .csv de los corpus
# Iterando sobre elemento 1125259 del .csv de los corpus
# Iterando sobre elemento 1125260 del .csv de los corpus
# Iterando sobre elemento 1125261 del .csv de los corpus
# Iterando sobre elemento 1125262 del .csv de los corpus
# Iterando sobre elemento 1125263 del .csv de los corpus
# Iterando sobre elemento 1125264 del .csv de los corpus
# Iterando sobre elemento 1125265 del .csv de los corpus
# Iterando sobre elemento 1125266 del .csv de los corpus
# Iterando sobre elemento 1125267 del .csv de los corpus
# Iterando sobre elemento 1125268 del .csv de los corpus
# Iterando sobre elemento 1125269 del .csv de los corpus
# Iterando sobre elemento 1125270 del .csv de los corpus
# Iterando sobre elemento 1125271 del .csv de los corpus
# Iterando sobre elemento 1125272 del .csv de los corpus
# Iterando sobre elemento 1125273 del .csv de los corpus
# Iterando sobre elemento 1125274 del .csv de los corpus
# Iterando sobre elemento 1125275 del .csv de los corpus
# Iterando sobre elemento 1125276 del .csv de los corpus
# Iterando sobre elemento 1125277 del .csv de los corpus
# Iterando sobre elemento 1125278 del .csv de los corpus
# Iterando sobre elemento 1125279 del .csv de los corpus
# Iterando sobre elemento 1125280 del .csv de los corpus
# Iterando sobre elemento 1125281 del .csv de los corpus
# Iterando sobre elemento 1125282 del .csv de los corpus
# Iterando sobre elemento 1125283 del .csv de los corpus
# Iterando sobre elemento 1125284 del .csv de los corpus
# Iterando sobre elemento 1125285 del .csv de los corpus
# Iterando sobre elemento 1125286 del .csv de los corpus
# Iterando sobre elemento 1125287 del .csv de los corpus
# Iterando sobre elemento 1125288 del .csv de los corpus
# Iterando sobre elemento 1125289 del .csv de los corpus
# Iterando sobre elemento 1125290 del .csv de los corpus
# Iterando sobre elemento 1125291 del .csv de los corpus
# Iterando sobre elemento 1125292 del .csv de los corpus
# Iterando sobre elemento 1125293 del .csv de los corpus
# Iterando sobre elemento 1125294 del .csv de los corpus
# Iterando sobre elemento 1125295 del .csv de los corpus
# Iterando sobre elemento 1125296 del .csv de los corpus
# Iterando sobre elemento 1125297 del .csv de los corpus
# Iterando sobre elemento 1125298 del .csv de los corpus
# Iterando sobre elemento 1125299 del .csv de los corpus
# Iterando sobre elemento 1125300 del .csv de los corpus
# Iterando sobre elemento 1125301 del .csv de los corpus
# Iterando sobre elemento 1125302 del .csv de los corpus
# Iterando sobre elemento 1125303 del .csv de los corpus
# Iterando sobre elemento 1125304 del .csv de los corpus
# Iterando sobre elemento 1125305 del .csv de los corpus
# Iterando sobre elemento 1125306 del .csv de los corpus
# Iterando sobre elemento 1125307 del .csv de los corpus
# Iterando sobre elemento 1125308 del .csv de los corpus
# Iterando sobre elemento 1125309 del .csv de los corpus
# Iterando sobre elemento 1125310 del .csv de los corpus
# Iterando sobre elemento 1125311 del .csv de los corpus
# Iterando sobre elemento 1125312 del .csv de los corpus
# Iterando sobre elemento 1125313 del .csv de los corpus
# Iterando sobre elemento 1125314 del .csv de los corpus
# Iterando sobre elemento 1125315 del .csv de los corpus
# Iterando sobre elemento 1125316 del .csv de los corpus
# Iterando sobre elemento 1125317 del .csv de los corpus
# Iterando sobre elemento 1125318 del .csv de los corpus
# Iterando sobre elemento 1125319 del .csv de los corpus
# Iterando sobre elemento 1125320 del .csv de los corpus
# Iterando sobre elemento 1125321 del .csv de los corpus
# Iterando sobre elemento 1125322 del .csv de los corpus
# Iterando sobre elemento 1125323 del .csv de los corpus
# Iterando sobre elemento 1125324 del .csv de los corpus
# Iterando sobre elemento 1125325 del .csv de los corpus
# Iterando sobre elemento 1125326 del .csv de los corpus
# Iterando sobre elemento 1125327 del .csv de los corpus
# Iterando sobre elemento 1125328 del .csv de los corpus
# Iterando sobre elemento 1125329 del .csv de los corpus
# Iterando sobre elemento 1125330 del .csv de los corpus
# Iterando sobre elemento 1125333 del .csv de los corpus
# Iterando sobre elemento 1125334 del .csv de los corpus
# Iterando sobre elemento 1125335 del .csv de los corpus
# Iterando sobre elemento 1125336 del .csv de los corpus
# Iterando sobre elemento 1125337 del .csv de los corpus
# Iterando sobre elemento 1125338 del .csv de los corpus
# Iterando sobre elemento 1125339 del .csv de los corpus
# Iterando sobre elemento 1125340 del .csv de los corpus
# Iterando sobre elemento 1125341 del .csv de los corpus
# Iterando sobre elemento 1125342 del .csv de los corpus
# Iterando sobre elemento 1125343 del .csv de los corpus
# Iterando sobre elemento 1125344 del .csv de los corpus
# Iterando sobre elemento 1125345 del .csv de los corpus
# Iterando sobre elemento 1125346 del .csv de los corpus
# Iterando sobre elemento 1125347 del .csv de los corpus
# Iterando sobre elemento 1125348 del .csv de los corpus
# Iterando sobre elemento 1125349 del .csv de los corpus
# Iterando sobre elemento 1125350 del .csv de los corpus
# Iterando sobre elemento 1125351 del .csv de los corpus
# Iterando sobre elemento 1125354 del .csv de los corpus
# Iterando sobre elemento 1125355 del .csv de los corpus
# Iterando sobre elemento 1125357 del .csv de los corpus
# Iterando sobre elemento 1125359 del .csv de los corpus
# Iterando sobre elemento 1125360 del .csv de los corpus
# Iterando sobre elemento 1125361 del .csv de los corpus
# Iterando sobre elemento 1125363 del .csv de los corpus
# Iterando sobre elemento 1125364 del .csv de los corpus
# Iterando sobre elemento 1125365 del .csv de los corpus
# Iterando sobre elemento 1125366 del .csv de los corpus
# Iterando sobre elemento 1125367 del .csv de los corpus
# Iterando sobre elemento 1125369 del .csv de los corpus
# Iterando sobre elemento 1125371 del .csv de los corpus
# Iterando sobre elemento 1125373 del .csv de los corpus
# Iterando sobre elemento 1125374 del .csv de los corpus
# Iterando sobre elemento 1125376 del .csv de los corpus
# Iterando sobre elemento 1125377 del .csv de los corpus
# Iterando sobre elemento 1125378 del .csv de los corpus
# Iterando sobre elemento 1125379 del .csv de los corpus
# Iterando sobre elemento 1125380 del .csv de los corpus
# Iterando sobre elemento 1125381 del .csv de los corpus
# Iterando sobre elemento 1125382 del .csv de los corpus
# Iterando sobre elemento 1125383 del .csv de los corpus
# Iterando sobre elemento 1125384 del .csv de los corpus
# Iterando sobre elemento 1125386 del .csv de los corpus
# Iterando sobre elemento 1125387 del .csv de los corpus
# Iterando sobre elemento 1125388 del .csv de los corpus
# Iterando sobre elemento 1125389 del .csv de los corpus
# Iterando sobre elemento 1125390 del .csv de los corpus
# Iterando sobre elemento 1125391 del .csv de los corpus
# Iterando sobre elemento 1125392 del .csv de los corpus
# Iterando sobre elemento 1125394 del .csv de los corpus
# Iterando sobre elemento 1125396 del .csv de los corpus
# Iterando sobre elemento 1125397 del .csv de los corpus
# Iterando sobre elemento 1125399 del .csv de los corpus
# Iterando sobre elemento 1125400 del .csv de los corpus
# Iterando sobre elemento 1125402 del .csv de los corpus
# Iterando sobre elemento 1125403 del .csv de los corpus
# Iterando sobre elemento 1125404 del .csv de los corpus
# Iterando sobre elemento 1125405 del .csv de los corpus
# Iterando sobre elemento 1125406 del .csv de los corpus
# Iterando sobre elemento 1125407 del .csv de los corpus
# Iterando sobre elemento 1125408 del .csv de los corpus
# Iterando sobre elemento 1125409 del .csv de los corpus
# Iterando sobre elemento 1125410 del .csv de los corpus
# Iterando sobre elemento 1125411 del .csv de los corpus
# Iterando sobre elemento 1125412 del .csv de los corpus
# Iterando sobre elemento 1125413 del .csv de los corpus
# Iterando sobre elemento 1125414 del .csv de los corpus
# Iterando sobre elemento 1125415 del .csv de los corpus
# Iterando sobre elemento 1125416 del .csv de los corpus
# Iterando sobre elemento 1125417 del .csv de los corpus
# Iterando sobre elemento 1125418 del .csv de los corpus
# Iterando sobre elemento 1125419 del .csv de los corpus
# Iterando sobre elemento 1125420 del .csv de los corpus
# Iterando sobre elemento 1125421 del .csv de los corpus
# Iterando sobre elemento 1125422 del .csv de los corpus
# Iterando sobre elemento 1125423 del .csv de los corpus
# Iterando sobre elemento 1125424 del .csv de los corpus
# Iterando sobre elemento 1125425 del .csv de los corpus
# Iterando sobre elemento 1125426 del .csv de los corpus
# Iterando sobre elemento 1125427 del .csv de los corpus
# Iterando sobre elemento 1125428 del .csv de los corpus
# Iterando sobre elemento 1125429 del .csv de los corpus
# Iterando sobre elemento 1125430 del .csv de los corpus
# Iterando sobre elemento 1125431 del .csv de los corpus
# Iterando sobre elemento 1125432 del .csv de los corpus
# Iterando sobre elemento 1125433 del .csv de los corpus
# Iterando sobre elemento 1125434 del .csv de los corpus
# Iterando sobre elemento 1125435 del .csv de los corpus
# Iterando sobre elemento 1125436 del .csv de los corpus
# Iterando sobre elemento 1125437 del .csv de los corpus
# Iterando sobre elemento 1125438 del .csv de los corpus
# Iterando sobre elemento 1125439 del .csv de los corpus
# Iterando sobre elemento 1125440 del .csv de los corpus
# Iterando sobre elemento 1125441 del .csv de los corpus
# Iterando sobre elemento 1125442 del .csv de los corpus
# Iterando sobre elemento 1125443 del .csv de los corpus
# Iterando sobre elemento 1125444 del .csv de los corpus
# Iterando sobre elemento 1125445 del .csv de los corpus
# Iterando sobre elemento 1125446 del .csv de los corpus
# Iterando sobre elemento 1125447 del .csv de los corpus
# Iterando sobre elemento 1125448 del .csv de los corpus
# Iterando sobre elemento 1125449 del .csv de los corpus
# Iterando sobre elemento 1125450 del .csv de los corpus
# Iterando sobre elemento 1125451 del .csv de los corpus
# Iterando sobre elemento 1125452 del .csv de los corpus
# Iterando sobre elemento 1125453 del .csv de los corpus
# Iterando sobre elemento 1125454 del .csv de los corpus
# Iterando sobre elemento 1125455 del .csv de los corpus
# Iterando sobre elemento 1125456 del .csv de los corpus
# Iterando sobre elemento 1125457 del .csv de los corpus
# Iterando sobre elemento 1125458 del .csv de los corpus
# Iterando sobre elemento 1125459 del .csv de los corpus
# Iterando sobre elemento 1125460 del .csv de los corpus
# Iterando sobre elemento 1125461 del .csv de los corpus
# Iterando sobre elemento 1125462 del .csv de los corpus
# Iterando sobre elemento 1125463 del .csv de los corpus
# Iterando sobre elemento 1125464 del .csv de los corpus
# Iterando sobre elemento 1125465 del .csv de los corpus
# Iterando sobre elemento 1125466 del .csv de los corpus
# Iterando sobre elemento 1125467 del .csv de los corpus
# Iterando sobre elemento 1125468 del .csv de los corpus
# Iterando sobre elemento 1125469 del .csv de los corpus
# Iterando sobre elemento 1125470 del .csv de los corpus
# Iterando sobre elemento 1125471 del .csv de los corpus
# Iterando sobre elemento 1125472 del .csv de los corpus
# Iterando sobre elemento 1125473 del .csv de los corpus
# Iterando sobre elemento 1125474 del .csv de los corpus
# Iterando sobre elemento 1125475 del .csv de los corpus
# Iterando sobre elemento 1125476 del .csv de los corpus
# Iterando sobre elemento 1125477 del .csv de los corpus
# Iterando sobre elemento 1125478 del .csv de los corpus
# Iterando sobre elemento 1125479 del .csv de los corpus
# Iterando sobre elemento 1125480 del .csv de los corpus
# Iterando sobre elemento 1125481 del .csv de los corpus
# Iterando sobre elemento 1125482 del .csv de los corpus
# Iterando sobre elemento 1125483 del .csv de los corpus
# Iterando sobre elemento 1125484 del .csv de los corpus
# Iterando sobre elemento 1125485 del .csv de los corpus
# Iterando sobre elemento 1125486 del .csv de los corpus
# Iterando sobre elemento 1125487 del .csv de los corpus
# Iterando sobre elemento 1125488 del .csv de los corpus
# Iterando sobre elemento 1125489 del .csv de los corpus
# Iterando sobre elemento 1125490 del .csv de los corpus
# Iterando sobre elemento 1125491 del .csv de los corpus
# Iterando sobre elemento 1125492 del .csv de los corpus
# Iterando sobre elemento 1125493 del .csv de los corpus
# Iterando sobre elemento 1125494 del .csv de los corpus
# Iterando sobre elemento 1125495 del .csv de los corpus
# Iterando sobre elemento 1125496 del .csv de los corpus
# Iterando sobre elemento 1125497 del .csv de los corpus
# Iterando sobre elemento 1125498 del .csv de los corpus
# Iterando sobre elemento 1125499 del .csv de los corpus
# Iterando sobre elemento 1125500 del .csv de los corpus
# Iterando sobre elemento 1125501 del .csv de los corpus
# Iterando sobre elemento 1125502 del .csv de los corpus
# Iterando sobre elemento 1125503 del .csv de los corpus
# Iterando sobre elemento 1125504 del .csv de los corpus
# Iterando sobre elemento 1125505 del .csv de los corpus
# Iterando sobre elemento 1125506 del .csv de los corpus
# Iterando sobre elemento 1125507 del .csv de los corpus
# Iterando sobre elemento 1125508 del .csv de los corpus
# Iterando sobre elemento 1125509 del .csv de los corpus
# Iterando sobre elemento 1125510 del .csv de los corpus
# Iterando sobre elemento 1125511 del .csv de los corpus
# Iterando sobre elemento 1125512 del .csv de los corpus
# Iterando sobre elemento 1125513 del .csv de los corpus
# Iterando sobre elemento 1125514 del .csv de los corpus
# Iterando sobre elemento 1125515 del .csv de los corpus
# Iterando sobre elemento 1125516 del .csv de los corpus
# Iterando sobre elemento 1125517 del .csv de los corpus
# Iterando sobre elemento 1125518 del .csv de los corpus
# Iterando sobre elemento 1125519 del .csv de los corpus
# Iterando sobre elemento 1125520 del .csv de los corpus
# Iterando sobre elemento 1125521 del .csv de los corpus
# Iterando sobre elemento 1125522 del .csv de los corpus
# Iterando sobre elemento 1125523 del .csv de los corpus
# Iterando sobre elemento 1125524 del .csv de los corpus
# Iterando sobre elemento 1125525 del .csv de los corpus
# Iterando sobre elemento 1125526 del .csv de los corpus
# Iterando sobre elemento 1125527 del .csv de los corpus
# Iterando sobre elemento 1125528 del .csv de los corpus
# Iterando sobre elemento 1125529 del .csv de los corpus
# Iterando sobre elemento 1125530 del .csv de los corpus
# Iterando sobre elemento 1125531 del .csv de los corpus
# Iterando sobre elemento 1125532 del .csv de los corpus
# Iterando sobre elemento 1125533 del .csv de los corpus
# Iterando sobre elemento 1125534 del .csv de los corpus
# Iterando sobre elemento 1125535 del .csv de los corpus
# Iterando sobre elemento 1125536 del .csv de los corpus
# Iterando sobre elemento 1125537 del .csv de los corpus
# Iterando sobre elemento 1125538 del .csv de los corpus
# Iterando sobre elemento 1125539 del .csv de los corpus
# Iterando sobre elemento 1125540 del .csv de los corpus
# Iterando sobre elemento 1125541 del .csv de los corpus
# Iterando sobre elemento 1125542 del .csv de los corpus
# Iterando sobre elemento 1125543 del .csv de los corpus
# Iterando sobre elemento 1125544 del .csv de los corpus
# Iterando sobre elemento 1125545 del .csv de los corpus
# Iterando sobre elemento 1125546 del .csv de los corpus
# Iterando sobre elemento 1125547 del .csv de los corpus
# Iterando sobre elemento 1125548 del .csv de los corpus
# Iterando sobre elemento 1125549 del .csv de los corpus
# Iterando sobre elemento 1125550 del .csv de los corpus
# Iterando sobre elemento 1125551 del .csv de los corpus
# Iterando sobre elemento 1125552 del .csv de los corpus
# Iterando sobre elemento 1125553 del .csv de los corpus
# Iterando sobre elemento 1125554 del .csv de los corpus
# Iterando sobre elemento 1125555 del .csv de los corpus
# Iterando sobre elemento 1125556 del .csv de los corpus
# Iterando sobre elemento 1125558 del .csv de los corpus
# Iterando sobre elemento 1125559 del .csv de los corpus
# Iterando sobre elemento 1125560 del .csv de los corpus
# Iterando sobre elemento 1125561 del .csv de los corpus
# Iterando sobre elemento 1125562 del .csv de los corpus
# Iterando sobre elemento 1125563 del .csv de los corpus
# Iterando sobre elemento 1125564 del .csv de los corpus
# Iterando sobre elemento 1125565 del .csv de los corpus
# Iterando sobre elemento 1125566 del .csv de los corpus
# Iterando sobre elemento 1125567 del .csv de los corpus
# Iterando sobre elemento 1125568 del .csv de los corpus
# Iterando sobre elemento 1125569 del .csv de los corpus
# Iterando sobre elemento 1125570 del .csv de los corpus
# Iterando sobre elemento 1125571 del .csv de los corpus
# Iterando sobre elemento 1125572 del .csv de los corpus
# Iterando sobre elemento 1125573 del .csv de los corpus
# Iterando sobre elemento 1125574 del .csv de los corpus
# Iterando sobre elemento 1125575 del .csv de los corpus
# Iterando sobre elemento 1125576 del .csv de los corpus
# Iterando sobre elemento 1125577 del .csv de los corpus
# Iterando sobre elemento 1125578 del .csv de los corpus
# Iterando sobre elemento 1125579 del .csv de los corpus
# Iterando sobre elemento 1125580 del .csv de los corpus
# Iterando sobre elemento 1125581 del .csv de los corpus
# Iterando sobre elemento 1125582 del .csv de los corpus
# Iterando sobre elemento 1125583 del .csv de los corpus
# Iterando sobre elemento 1125584 del .csv de los corpus
# Iterando sobre elemento 1125585 del .csv de los corpus
# Iterando sobre elemento 1125586 del .csv de los corpus
# Iterando sobre elemento 1125587 del .csv de los corpus
# Iterando sobre elemento 1125588 del .csv de los corpus
# Iterando sobre elemento 1125589 del .csv de los corpus
# Iterando sobre elemento 1125590 del .csv de los corpus
# Iterando sobre elemento 1125591 del .csv de los corpus
# Iterando sobre elemento 1125592 del .csv de los corpus
# Iterando sobre elemento 1125593 del .csv de los corpus
# Iterando sobre elemento 1125594 del .csv de los corpus
# Iterando sobre elemento 1125595 del .csv de los corpus
# Iterando sobre elemento 1125596 del .csv de los corpus
# Iterando sobre elemento 1125597 del .csv de los corpus
# Iterando sobre elemento 1125598 del .csv de los corpus
# Iterando sobre elemento 1125599 del .csv de los corpus
# Iterando sobre elemento 1125600 del .csv de los corpus
# Iterando sobre elemento 1125601 del .csv de los corpus
# Iterando sobre elemento 1125602 del .csv de los corpus
# Iterando sobre elemento 1125603 del .csv de los corpus
# Iterando sobre elemento 1125604 del .csv de los corpus
# Iterando sobre elemento 1125605 del .csv de los corpus
# Iterando sobre elemento 1125606 del .csv de los corpus
# Iterando sobre elemento 1125607 del .csv de los corpus
# Iterando sobre elemento 1125608 del .csv de los corpus
# Iterando sobre elemento 1125609 del .csv de los corpus
# Iterando sobre elemento 1125610 del .csv de los corpus
# Iterando sobre elemento 1125611 del .csv de los corpus
# Iterando sobre elemento 1125612 del .csv de los corpus
# Iterando sobre elemento 1125613 del .csv de los corpus
# Iterando sobre elemento 1125614 del .csv de los corpus
# Iterando sobre elemento 1125615 del .csv de los corpus
# Iterando sobre elemento 1125616 del .csv de los corpus
# Iterando sobre elemento 1125617 del .csv de los corpus
# Iterando sobre elemento 1125618 del .csv de los corpus
# Iterando sobre elemento 1125619 del .csv de los corpus
# Iterando sobre elemento 1125620 del .csv de los corpus
# Iterando sobre elemento 1125621 del .csv de los corpus
# Iterando sobre elemento 1125622 del .csv de los corpus
# Iterando sobre elemento 1125623 del .csv de los corpus
# Iterando sobre elemento 1125624 del .csv de los corpus
# Iterando sobre elemento 1125625 del .csv de los corpus
# Iterando sobre elemento 1125626 del .csv de los corpus
# Iterando sobre elemento 1125627 del .csv de los corpus
# Iterando sobre elemento 1125628 del .csv de los corpus
# Iterando sobre elemento 1125629 del .csv de los corpus
# Iterando sobre elemento 1125630 del .csv de los corpus
# Iterando sobre elemento 1125631 del .csv de los corpus
# Iterando sobre elemento 1125632 del .csv de los corpus
# Iterando sobre elemento 1125633 del .csv de los corpus
# Iterando sobre elemento 1125634 del .csv de los corpus
# Iterando sobre elemento 1125635 del .csv de los corpus
# Iterando sobre elemento 1125636 del .csv de los corpus
# Iterando sobre elemento 1125637 del .csv de los corpus
# Iterando sobre elemento 1125638 del .csv de los corpus
# Iterando sobre elemento 1125639 del .csv de los corpus
# Iterando sobre elemento 1125640 del .csv de los corpus
# Iterando sobre elemento 1125641 del .csv de los corpus
# Iterando sobre elemento 1125642 del .csv de los corpus
# Iterando sobre elemento 1125643 del .csv de los corpus
# Iterando sobre elemento 1125644 del .csv de los corpus
# Iterando sobre elemento 1125645 del .csv de los corpus
# Iterando sobre elemento 1125646 del .csv de los corpus
# Iterando sobre elemento 1125647 del .csv de los corpus
# Iterando sobre elemento 1125648 del .csv de los corpus
# Iterando sobre elemento 1125649 del .csv de los corpus
# Iterando sobre elemento 1125650 del .csv de los corpus
# Iterando sobre elemento 1125651 del .csv de los corpus
# Iterando sobre elemento 1125652 del .csv de los corpus
# Iterando sobre elemento 1125653 del .csv de los corpus
# Iterando sobre elemento 1125654 del .csv de los corpus
# Iterando sobre elemento 1125655 del .csv de los corpus
# Iterando sobre elemento 1125656 del .csv de los corpus
# Iterando sobre elemento 1125657 del .csv de los corpus
# Iterando sobre elemento 1125658 del .csv de los corpus
# Iterando sobre elemento 1125659 del .csv de los corpus
# Iterando sobre elemento 1125660 del .csv de los corpus
# Iterando sobre elemento 1125661 del .csv de los corpus
# Iterando sobre elemento 1125662 del .csv de los corpus
# Iterando sobre elemento 1125663 del .csv de los corpus
# Iterando sobre elemento 1125664 del .csv de los corpus
# Iterando sobre elemento 1125665 del .csv de los corpus
# Iterando sobre elemento 1125666 del .csv de los corpus
# Iterando sobre elemento 1125667 del .csv de los corpus
# Iterando sobre elemento 1125668 del .csv de los corpus
# Iterando sobre elemento 1125669 del .csv de los corpus
# Iterando sobre elemento 1125670 del .csv de los corpus
# Iterando sobre elemento 1125671 del .csv de los corpus
# Iterando sobre elemento 1125672 del .csv de los corpus
# Iterando sobre elemento 1125673 del .csv de los corpus
# Iterando sobre elemento 1125674 del .csv de los corpus
# Iterando sobre elemento 1125675 del .csv de los corpus
# Iterando sobre elemento 1125676 del .csv de los corpus
# Iterando sobre elemento 1125677 del .csv de los corpus
# Iterando sobre elemento 1125678 del .csv de los corpus
# Iterando sobre elemento 1125679 del .csv de los corpus
# Iterando sobre elemento 1125680 del .csv de los corpus
# Iterando sobre elemento 1125681 del .csv de los corpus
# Iterando sobre elemento 1125682 del .csv de los corpus
# Iterando sobre elemento 1125683 del .csv de los corpus
# Iterando sobre elemento 1125684 del .csv de los corpus
# Iterando sobre elemento 1125685 del .csv de los corpus
# Iterando sobre elemento 1125686 del .csv de los corpus
# Iterando sobre elemento 1125687 del .csv de los corpus
# Iterando sobre elemento 1125688 del .csv de los corpus
# Iterando sobre elemento 1125689 del .csv de los corpus
# Iterando sobre elemento 1125690 del .csv de los corpus
# Iterando sobre elemento 1125691 del .csv de los corpus
# Iterando sobre elemento 1125692 del .csv de los corpus
# Iterando sobre elemento 1125693 del .csv de los corpus
# Iterando sobre elemento 1125694 del .csv de los corpus
# Iterando sobre elemento 1125695 del .csv de los corpus
# Iterando sobre elemento 1125696 del .csv de los corpus
# Iterando sobre elemento 1125697 del .csv de los corpus
# Iterando sobre elemento 1125698 del .csv de los corpus
# Iterando sobre elemento 1125699 del .csv de los corpus
# Iterando sobre elemento 1125700 del .csv de los corpus
# Iterando sobre elemento 1125701 del .csv de los corpus
# Iterando sobre elemento 1125702 del .csv de los corpus
# Iterando sobre elemento 1125703 del .csv de los corpus
# Iterando sobre elemento 1125704 del .csv de los corpus
# Iterando sobre elemento 1125705 del .csv de los corpus
# Iterando sobre elemento 1125706 del .csv de los corpus
# Iterando sobre elemento 1125707 del .csv de los corpus
# Iterando sobre elemento 1125708 del .csv de los corpus
# Iterando sobre elemento 1125709 del .csv de los corpus
# Iterando sobre elemento 1125710 del .csv de los corpus
# Iterando sobre elemento 1125711 del .csv de los corpus
# Iterando sobre elemento 1125712 del .csv de los corpus
# Iterando sobre elemento 1125713 del .csv de los corpus
# Iterando sobre elemento 1125714 del .csv de los corpus
# Iterando sobre elemento 1125715 del .csv de los corpus
# Iterando sobre elemento 1125716 del .csv de los corpus
# Iterando sobre elemento 1125717 del .csv de los corpus
# Iterando sobre elemento 1125718 del .csv de los corpus
# Iterando sobre elemento 1125719 del .csv de los corpus
# Iterando sobre elemento 1125720 del .csv de los corpus
# Iterando sobre elemento 1125721 del .csv de los corpus
# Iterando sobre elemento 1125722 del .csv de los corpus
# Iterando sobre elemento 1125723 del .csv de los corpus
# Iterando sobre elemento 1125724 del .csv de los corpus
# Iterando sobre elemento 1125725 del .csv de los corpus
# Iterando sobre elemento 1125726 del .csv de los corpus
# Iterando sobre elemento 1125727 del .csv de los corpus
# Iterando sobre elemento 1125728 del .csv de los corpus
# Iterando sobre elemento 1125729 del .csv de los corpus
# Iterando sobre elemento 1125730 del .csv de los corpus
# Iterando sobre elemento 1125731 del .csv de los corpus
# Iterando sobre elemento 1125732 del .csv de los corpus
# Iterando sobre elemento 1125733 del .csv de los corpus
# Iterando sobre elemento 1125734 del .csv de los corpus
# Iterando sobre elemento 1125735 del .csv de los corpus
# Iterando sobre elemento 1125736 del .csv de los corpus
# Iterando sobre elemento 1125737 del .csv de los corpus
# Iterando sobre elemento 1125738 del .csv de los corpus
# Iterando sobre elemento 1125739 del .csv de los corpus
# Iterando sobre elemento 1125740 del .csv de los corpus
# Iterando sobre elemento 1125741 del .csv de los corpus
# Iterando sobre elemento 1125742 del .csv de los corpus
# Iterando sobre elemento 1125744 del .csv de los corpus
# Iterando sobre elemento 1125745 del .csv de los corpus
# Iterando sobre elemento 1125746 del .csv de los corpus
# Iterando sobre elemento 1125747 del .csv de los corpus
# Iterando sobre elemento 1125748 del .csv de los corpus
# Iterando sobre elemento 1125749 del .csv de los corpus
# Iterando sobre elemento 1125750 del .csv de los corpus
# Iterando sobre elemento 1125751 del .csv de los corpus
# Iterando sobre elemento 1125752 del .csv de los corpus
# Iterando sobre elemento 1125753 del .csv de los corpus
# Iterando sobre elemento 1125754 del .csv de los corpus
# Iterando sobre elemento 1125755 del .csv de los corpus
# Iterando sobre elemento 1125756 del .csv de los corpus
# Iterando sobre elemento 1125757 del .csv de los corpus
# Iterando sobre elemento 1125758 del .csv de los corpus
# Iterando sobre elemento 1125759 del .csv de los corpus
# Iterando sobre elemento 1125760 del .csv de los corpus
# Iterando sobre elemento 1125761 del .csv de los corpus
# Iterando sobre elemento 1125762 del .csv de los corpus
# Iterando sobre elemento 1125763 del .csv de los corpus
# Iterando sobre elemento 1125764 del .csv de los corpus
# Iterando sobre elemento 1125765 del .csv de los corpus
# Iterando sobre elemento 1125766 del .csv de los corpus
# Iterando sobre elemento 1125767 del .csv de los corpus
# Iterando sobre elemento 1125768 del .csv de los corpus
# Iterando sobre elemento 1125769 del .csv de los corpus
# Iterando sobre elemento 1125770 del .csv de los corpus
# Iterando sobre elemento 1125771 del .csv de los corpus
# Iterando sobre elemento 1125772 del .csv de los corpus
# Iterando sobre elemento 1125773 del .csv de los corpus
# Iterando sobre elemento 1125774 del .csv de los corpus
# Iterando sobre elemento 1125775 del .csv de los corpus
# Iterando sobre elemento 1125776 del .csv de los corpus
# Iterando sobre elemento 1125777 del .csv de los corpus
# Iterando sobre elemento 1125778 del .csv de los corpus
# Iterando sobre elemento 1125779 del .csv de los corpus
# Iterando sobre elemento 1125780 del .csv de los corpus
# Iterando sobre elemento 1125781 del .csv de los corpus
# ...
# Iterando sobre elemento 1129715 del .csv de los corpus
# Iterando sobre elemento 1129716 del .csv de los corpus
# Iterando sobre elemento 1129717 del .csv de los corpus
# Iterando sobre elemento 1129718 del .csv de los corpus
# Iterando sobre elemento 1129719 del .csv de los corpus
# Iterando sobre elemento 1129720 del .csv de los corpus
# Iterando sobre elemento 1129721 del .csv de los corpus
# Iterando sobre elemento 1129722 del .csv de los corpus
# Iterando sobre elemento 1129723 del .csv de los corpus
# Iterando sobre elemento 1129724 del .csv de los corpus
# Iterando sobre elemento 1129725 del .csv de los corpus
# Iterando sobre elemento 1129726 del .csv de los corpus
# Iterando sobre elemento 1129727 del .csv de los corpus
# Iterando sobre elemento 1129728 del .csv de los corpus
# Iterando sobre elemento 1129729 del .csv de los corpus
# Iterando sobre elemento 1129730 del .csv de los corpus
# Iterando sobre elemento 1129731 del .csv de los corpus
# Iterando sobre elemento 1129732 del .csv de los corpus
# Iterando sobre elemento 1129733 del .csv de los corpus
# Iterando sobre elemento 1129734 del .csv de los corpus
# Iterando sobre elemento 1129735 del .csv de los corpus
# Iterando sobre elemento 1129736 del .csv de los corpus
# Iterando sobre elemento 1129737 del .csv de los corpus
# Iterando sobre elemento 1129738 del .csv de los corpus
# Iterando sobre elemento 1129739 del .csv de los corpus
# Iterando sobre elemento 1129740 del .csv de los corpus
# Iterando sobre elemento 1129741 del .csv de los corpus
# Iterando sobre elemento 1129742 del .csv de los corpus
# Iterando sobre elemento 1129743 del .csv de los corpus
# Iterando sobre elemento 1129744 del .csv de los corpus
# Iterando sobre elemento 1129745 del .csv de los corpus
# Iterando sobre elemento 1129746 del .csv de los corpus
# Iterando sobre elemento 1129747 del .csv de los corpus
# Iterando sobre elemento 1129748 del .csv de los corpus
# Iterando sobre elemento 1129749 del .csv de los corpus
# Iterando sobre elemento 1129750 del .csv de los corpus
# Iterando sobre elemento 1129751 del .csv de los corpus
# Iterando sobre elemento 1129752 del .csv de los corpus
# Iterando sobre elemento 1129753 del .csv de los corpus
# Iterando sobre elemento 1129754 del .csv de los corpus
# Iterando sobre elemento 1129755 del .csv de los corpus
# Iterando sobre elemento 1129756 del .csv de los corpus
# Iterando sobre elemento 1129757 del .csv de los corpus
# Iterando sobre elemento 1129758 del .csv de los corpus
# Iterando sobre elemento 1129759 del .csv de los corpus
# Iterando sobre elemento 1129760 del .csv de los corpus
# Iterando sobre elemento 1129761 del .csv de los corpus
# Iterando sobre elemento 1129762 del .csv de los corpus
# Iterando sobre elemento 1129763 del .csv de los corpus
# Iterando sobre elemento 1129764 del .csv de los corpus
# Iterando sobre elemento 1129765 del .csv de los corpus
# Iterando sobre elemento 1129766 del .csv de los corpus
# Iterando sobre elemento 1129767 del .csv de los corpus
# Iterando sobre elemento 1129768 del .csv de los corpus
# Iterando sobre elemento 1129769 del .csv de los corpus
# Iterando sobre elemento 1129770 del .csv de los corpus
# Iterando sobre elemento 1129771 del .csv de los corpus
# Iterando sobre elemento 1129772 del .csv de los corpus
# Iterando sobre elemento 1129773 del .csv de los corpus
# Iterando sobre elemento 1129774 del .csv de los corpus
# Iterando sobre elemento 1129775 del .csv de los corpus
# Iterando sobre elemento 1129776 del .csv de los corpus
# Iterando sobre elemento 1129777 del .csv de los corpus
# Iterando sobre elemento 1129778 del .csv de los corpus
# Iterando sobre elemento 1129779 del .csv de los corpus
# Iterando sobre elemento 1129780 del .csv de los corpus
# Iterando sobre elemento 1129781 del .csv de los corpus
# Iterando sobre elemento 1129782 del .csv de los corpus
# Iterando sobre elemento 1129783 del .csv de los corpus
# Iterando sobre elemento 1129784 del .csv de los corpus
# Iterando sobre elemento 1129785 del .csv de los corpus
# Iterando sobre elemento 1129786 del .csv de los corpus
# Iterando sobre elemento 1129787 del .csv de los corpus
# Iterando sobre elemento 1129788 del .csv de los corpus
# Iterando sobre elemento 1129789 del .csv de los corpus
# Iterando sobre elemento 1129790 del .csv de los corpus
# Iterando sobre elemento 1129791 del .csv de los corpus
# Iterando sobre elemento 1129792 del .csv de los corpus
# Iterando sobre elemento 1129793 del .csv de los corpus
# Iterando sobre elemento 1129794 del .csv de los corpus
# Iterando sobre elemento 1129795 del .csv de los corpus
# Iterando sobre elemento 1129796 del .csv de los corpus
# Iterando sobre elemento 1129797 del .csv de los corpus
# Iterando sobre elemento 1129798 del .csv de los corpus
# Iterando sobre elemento 1129799 del .csv de los corpus
# Iterando sobre elemento 1129800 del .csv de los corpus
# Iterando sobre elemento 1129801 del .csv de los corpus
# Iterando sobre elemento 1129802 del .csv de los corpus
# Iterando sobre elemento 1129803 del .csv de los corpus
# Iterando sobre elemento 1129804 del .csv de los corpus
# Iterando sobre elemento 1129805 del .csv de los corpus
# Iterando sobre elemento 1129806 del .csv de los corpus
# Iterando sobre elemento 1129807 del .csv de los corpus
# Iterando sobre elemento 1129808 del .csv de los corpus
# Iterando sobre elemento 1129809 del .csv de los corpus
# Iterando sobre elemento 1129810 del .csv de los corpus
# Iterando sobre elemento 1129811 del .csv de los corpus
# Iterando sobre elemento 1129812 del .csv de los corpus
# Iterando sobre elemento 1129813 del .csv de los corpus
# Iterando sobre elemento 1129814 del .csv de los corpus
# Iterando sobre elemento 1129815 del .csv de los corpus
# Iterando sobre elemento 1129816 del .csv de los corpus
# Iterando sobre elemento 1129817 del .csv de los corpus
# Iterando sobre elemento 1129818 del .csv de los corpus
# Iterando sobre elemento 1129819 del .csv de los corpus
# Iterando sobre elemento 1129820 del .csv de los corpus
# Iterando sobre elemento 1129821 del .csv de los corpus
# Iterando sobre elemento 1129822 del .csv de los corpus
# Iterando sobre elemento 1129823 del .csv de los corpus
# Iterando sobre elemento 1129824 del .csv de los corpus
# Iterando sobre elemento 1129825 del .csv de los corpus
# Iterando sobre elemento 1129826 del .csv de los corpus
# Iterando sobre elemento 1129827 del .csv de los corpus
# Iterando sobre elemento 1129828 del .csv de los corpus
# Iterando sobre elemento 1129829 del .csv de los corpus
# Iterando sobre elemento 1129830 del .csv de los corpus
# Iterando sobre elemento 1129831 del .csv de los corpus
# Iterando sobre elemento 1129832 del .csv de los corpus
# Iterando sobre elemento 1129833 del .csv de los corpus
# Iterando sobre elemento 1129834 del .csv de los corpus
# Iterando sobre elemento 1129835 del .csv de los corpus
# Iterando sobre elemento 1129836 del .csv de los corpus
# Iterando sobre elemento 1129837 del .csv de los corpus
# Iterando sobre elemento 1129838 del .csv de los corpus
# Iterando sobre elemento 1129839 del .csv de los corpus
# Iterando sobre elemento 1129840 del .csv de los corpus
# Iterando sobre elemento 1129841 del .csv de los corpus
# Iterando sobre elemento 1129842 del .csv de los corpus
# Iterando sobre elemento 1129843 del .csv de los corpus
# Iterando sobre elemento 1129844 del .csv de los corpus
# Iterando sobre elemento 1129845 del .csv de los corpus
# Iterando sobre elemento 1129846 del .csv de los corpus
# Iterando sobre elemento 1129847 del .csv de los corpus
# Iterando sobre elemento 1129848 del .csv de los corpus
# Iterando sobre elemento 1129849 del .csv de los corpus
# Iterando sobre elemento 1129850 del .csv de los corpus
# Iterando sobre elemento 1129851 del .csv de los corpus
# Iterando sobre elemento 1129852 del .csv de los corpus
# Iterando sobre elemento 1129853 del .csv de los corpus
# Iterando sobre elemento 1129854 del .csv de los corpus
# Iterando sobre elemento 1129855 del .csv de los corpus
# Iterando sobre elemento 1129856 del .csv de los corpus
# Iterando sobre elemento 1129857 del .csv de los corpus
# Iterando sobre elemento 1129858 del .csv de los corpus
# Iterando sobre elemento 1129859 del .csv de los corpus
# Iterando sobre elemento 1129860 del .csv de los corpus
# Iterando sobre elemento 1129861 del .csv de los corpus
# Iterando sobre elemento 1129862 del .csv de los corpus
# Iterando sobre elemento 1129863 del .csv de los corpus
# Iterando sobre elemento 1129864 del .csv de los corpus
# Iterando sobre elemento 1129865 del .csv de los corpus
# Iterando sobre elemento 1129866 del .csv de los corpus
# Iterando sobre elemento 1129867 del .csv de los corpus
# Iterando sobre elemento 1129868 del .csv de los corpus
# Iterando sobre elemento 1129869 del .csv de los corpus
# Iterando sobre elemento 1129870 del .csv de los corpus
# Iterando sobre elemento 1129871 del .csv de los corpus
# Iterando sobre elemento 1129872 del .csv de los corpus
# Iterando sobre elemento 1129873 del .csv de los corpus
# Iterando sobre elemento 1129874 del .csv de los corpus
# Iterando sobre elemento 1129875 del .csv de los corpus
# Iterando sobre elemento 1129876 del .csv de los corpus
# Iterando sobre elemento 1129877 del .csv de los corpus
# Iterando sobre elemento 1129878 del .csv de los corpus
# Iterando sobre elemento 1129879 del .csv de los corpus
# Iterando sobre elemento 1129880 del .csv de los corpus
# Iterando sobre elemento 1129881 del .csv de los corpus
# Iterando sobre elemento 1129882 del .csv de los corpus
# Iterando sobre elemento 1129883 del .csv de los corpus
# Iterando sobre elemento 1129884 del .csv de los corpus
# Iterando sobre elemento 1129885 del .csv de los corpus
# Iterando sobre elemento 1129886 del .csv de los corpus
# Iterando sobre elemento 1129887 del .csv de los corpus
# Iterando sobre elemento 1129888 del .csv de los corpus
# Iterando sobre elemento 1129889 del .csv de los corpus
# Iterando sobre elemento 1129890 del .csv de los corpus
# Iterando sobre elemento 1129891 del .csv de los corpus
# Iterando sobre elemento 1129892 del .csv de los corpus
# Iterando sobre elemento 1129893 del .csv de los corpus
# Iterando sobre elemento 1129894 del .csv de los corpus
# Iterando sobre elemento 1129895 del .csv de los corpus
# Iterando sobre elemento 1129896 del .csv de los corpus
# Iterando sobre elemento 1129897 del .csv de los corpus
# Iterando sobre elemento 1129898 del .csv de los corpus
# Iterando sobre elemento 1129899 del .csv de los corpus
# Iterando sobre elemento 1129900 del .csv de los corpus
# Iterando sobre elemento 1129901 del .csv de los corpus
# Iterando sobre elemento 1129902 del .csv de los corpus
# Iterando sobre elemento 1129903 del .csv de los corpus
# Iterando sobre elemento 1129904 del .csv de los corpus
# Iterando sobre elemento 1129905 del .csv de los corpus
# Iterando sobre elemento 1129906 del .csv de los corpus
# Iterando sobre elemento 1129907 del .csv de los corpus
# Iterando sobre elemento 1129908 del .csv de los corpus
# Iterando sobre elemento 1129909 del .csv de los corpus
# Iterando sobre elemento 1129910 del .csv de los corpus
# Iterando sobre elemento 1129911 del .csv de los corpus
# Iterando sobre elemento 1129912 del .csv de los corpus
# Iterando sobre elemento 1129913 del .csv de los corpus
# Iterando sobre elemento 1129914 del .csv de los corpus
# Iterando sobre elemento 1129915 del .csv de los corpus
# Iterando sobre elemento 1129916 del .csv de los corpus
# Iterando sobre elemento 1129917 del .csv de los corpus
# Iterando sobre elemento 1129918 del .csv de los corpus
# Iterando sobre elemento 1129919 del .csv de los corpus
# Iterando sobre elemento 1129920 del .csv de los corpus
# Iterando sobre elemento 1129921 del .csv de los corpus
# Iterando sobre elemento 1129922 del .csv de los corpus
# Iterando sobre elemento 1129923 del .csv de los corpus
# Iterando sobre elemento 1129924 del .csv de los corpus
# Iterando sobre elemento 1129925 del .csv de los corpus
# Iterando sobre elemento 1129926 del .csv de los corpus
# Iterando sobre elemento 1129927 del .csv de los corpus
# Iterando sobre elemento 1129928 del .csv de los corpus
# Iterando sobre elemento 1129929 del .csv de los corpus
# Iterando sobre elemento 1129930 del .csv de los corpus
# Iterando sobre elemento 1129931 del .csv de los corpus
# Iterando sobre elemento 1129932 del .csv de los corpus
# Iterando sobre elemento 1129933 del .csv de los corpus
# Iterando sobre elemento 1129934 del .csv de los corpus
# Iterando sobre elemento 1129935 del .csv de los corpus
# Iterando sobre elemento 1129936 del .csv de los corpus
# Iterando sobre elemento 1129937 del .csv de los corpus
# Iterando sobre elemento 1129938 del .csv de los corpus
# Iterando sobre elemento 1129939 del .csv de los corpus
# Iterando sobre elemento 1129940 del .csv de los corpus
# Iterando sobre elemento 1129941 del .csv de los corpus
# Iterando sobre elemento 1129942 del .csv de los corpus
# Iterando sobre elemento 1129943 del .csv de los corpus
# Iterando sobre elemento 1129944 del .csv de los corpus
# Iterando sobre elemento 1129945 del .csv de los corpus
# Iterando sobre elemento 1129946 del .csv de los corpus
# Iterando sobre elemento 1129947 del .csv de los corpus
# Iterando sobre elemento 1129948 del .csv de los corpus
# Iterando sobre elemento 1129949 del .csv de los corpus
# Iterando sobre elemento 1129950 del .csv de los corpus
# Iterando sobre elemento 1129951 del .csv de los corpus
# Iterando sobre elemento 1129952 del .csv de los corpus
# Iterando sobre elemento 1129953 del .csv de los corpus
# Iterando sobre elemento 1129954 del .csv de los corpus
# Iterando sobre elemento 1129955 del .csv de los corpus
# Iterando sobre elemento 1129956 del .csv de los corpus
# Iterando sobre elemento 1129957 del .csv de los corpus
# Iterando sobre elemento 1129958 del .csv de los corpus
# Iterando sobre elemento 1129959 del .csv de los corpus
# Iterando sobre elemento 1129960 del .csv de los corpus
# Iterando sobre elemento 1129961 del .csv de los corpus
# Iterando sobre elemento 1129962 del .csv de los corpus
# Iterando sobre elemento 1129963 del .csv de los corpus
# Iterando sobre elemento 1129964 del .csv de los corpus
# Iterando sobre elemento 1129965 del .csv de los corpus
# Iterando sobre elemento 1129966 del .csv de los corpus
# Iterando sobre elemento 1129967 del .csv de los corpus
# Iterando sobre elemento 1129968 del .csv de los corpus
# Iterando sobre elemento 1129969 del .csv de los corpus
# Iterando sobre elemento 1129970 del .csv de los corpus
# Iterando sobre elemento 1129971 del .csv de los corpus
# Iterando sobre elemento 1129972 del .csv de los corpus
# Iterando sobre elemento 1129973 del .csv de los corpus
# Iterando sobre elemento 1129974 del .csv de los corpus
# Iterando sobre elemento 1129975 del .csv de los corpus
# Iterando sobre elemento 1129976 del .csv de los corpus
# Iterando sobre elemento 1129978 del .csv de los corpus
# Iterando sobre elemento 1129980 del .csv de los corpus
# Iterando sobre elemento 1129981 del .csv de los corpus
# Iterando sobre elemento 1129983 del .csv de los corpus
# Iterando sobre elemento 1129984 del .csv de los corpus
# Iterando sobre elemento 1129985 del .csv de los corpus
# Iterando sobre elemento 1129986 del .csv de los corpus
# Iterando sobre elemento 1129988 del .csv de los corpus
# Iterando sobre elemento 1129989 del .csv de los corpus
# Iterando sobre elemento 1129990 del .csv de los corpus
# Iterando sobre elemento 1129995 del .csv de los corpus
# Iterando sobre elemento 1129997 del .csv de los corpus
# Iterando sobre elemento 1129998 del .csv de los corpus
# Iterando sobre elemento 1129999 del .csv de los corpus
# Iterando sobre elemento 1130000 del .csv de los corpus
# Iterando sobre elemento 1130001 del .csv de los corpus
# Iterando sobre elemento 1130002 del .csv de los corpus
# Iterando sobre elemento 1130003 del .csv de los corpus
# Iterando sobre elemento 1130004 del .csv de los corpus
# Iterando sobre elemento 1130005 del .csv de los corpus
# Iterando sobre elemento 1130006 del .csv de los corpus
# Iterando sobre elemento 1130007 del .csv de los corpus
# Iterando sobre elemento 1130008 del .csv de los corpus
# Iterando sobre elemento 1130009 del .csv de los corpus
# Iterando sobre elemento 1130014 del .csv de los corpus
# Iterando sobre elemento 1130015 del .csv de los corpus
# Iterando sobre elemento 1130016 del .csv de los corpus
# Iterando sobre elemento 1130017 del .csv de los corpus

# %%
# Guardar corpus en un nuevo archivo .csv
df_tomatoes_critics.to_csv("tomatoes_data/rotten_tomatoes_critic_reviews_preproc.csv", index=False)

# %% [markdown]
# ### 3. Representación de datos en espacio vectorial:
#
# Vamos a utilizar TF-IDF para vectorizar nuestro corpus y representarlo como un espacio vectorial.
#
# La función implementada para este fin devolverá el corpus vectorizado y el vectorizador usado.

# %%
# Lectura del nuevo archivo .csv de tomatoes preprocesado

df_tomatoes_critics_preproc = pd.read_csv("tomatoes_data/rotten_tomatoes_critic_reviews_preproc.csv")
df_tomatoes_critics_preproc["review_content"] = df_tomatoes_critics_preproc["review_content"].astype("string")
df_tomatoes_critics_preproc["contenido_preproc_str"] = df_tomatoes_critics_preproc["contenido_preproc_str"].astype("string")
df_tomatoes_critics_preproc = df_tomatoes_critics_preproc.dropna(subset=["contenido_preproc_str"])

# %%
# ---- TF-IDF ----
def vectorize_tfidf(corpus):
    """
    Vectoriza un corpus utilizando TF-IDF.
    """
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(corpus)
    return X, vectorizer

# %%
# Vectorizar el corpus con TF-IDF
print("Vectorizando con TF-IDF")
X_tfidf, tfidf_vectorizer = vectorize_tfidf(df_tomatoes_critics_preproc["contenido_preproc_str"])
# Out:
# Vectorizando con TF-IDF

# %% [markdown]
# ### 4. Búsqueda de una consulta utilizando distancia coseno
#
# Vamos a implementar una función para realizar la búsqueda, dicha función recibirá la consulta, el corpus vectorizado y el vectorizador TF-IDF utilizado.
#
# 1. Preprocesará la consulta
# 2. Vectorizará la consulta
# 3. Calculará similitud coseno respecto al corpus
# 4. Devolverá los resultados relevantes

# %%
def buscar_documentos(consulta, corpus_vectorizado, vectorizador, metodo="tfidf"):
    """
    Busca documentos en el corpus y devuelve los más relevantes según el método elegido (BoW, TF-IDF, Word2Vec).
    """

    # Preprocesar la consulta
    consulta = preprocesar_contenido(consulta)

    # Vectorizar la consulta
    consulta_vec = vectorizador.transform([consulta])

    # Calcular similitudes
    similitudes = cosine_similarity(consulta_vec, corpus_vectorizado)
    resultados = similitudes[0]

    # Rankear documentos por relevancia y tomar los top_n
    indices_ordenados = resultados.argsort()[::-1]

    return indices_ordenados, resultados

# %%
# Definir la consulta y el máximo de resultados a mostrar
consulta = "Harry Potter"
max_resultados = 20

# %%
# ---- Obtener índices ordenados y hacer merge con df_tomatoes_movies ----
indices_ordenados, resultados = buscar_documentos(consulta, X_tfidf, tfidf_vectorizer)

# Realizar un merge entre los DataFrames basado en rotten_tomatoes_link
df_combined = pd.merge(
    df_tomatoes_critics_preproc,
    df_tomatoes_movies[["rotten_tomatoes_link", "movie_title"]],
    on="rotten_tomatoes_link",
    how="left"
)

# Ahora puedes usar df_combined para acceder tanto a las reseñas como a los títulos
resultados_detallados = [
    {
        "Película": df_combined.loc[indice, "movie_title"],  # Título de la película
        "Relevancia": resultados[indice],  # Relevancia calculada
        "Contenido reseña": df_combined.loc[indice, "review_content"],  # Contenido de la reseña
    }
    for indice in indices_ordenados
]

# %%
# Finalmente, mostrar los resultados
print("")
print(f"Mostrando resultados relevantes para la búsqueda:   {consulta}")
print("")
for resultado in resultados_detallados[:max_resultados]:
    print(f"\nPelícula: {resultado['Película']}, \nRelevancia: {resultado['Relevancia']:.3f}")
    print(f"Reseña: {resultado['Contenido reseña']}\n")
    print("=====================================================================================================================")
# Out:
# Mostrando resultados relevantes para la búsqueda:   Harry Potter
#
#
# Película: Harry Potter and the Half-Blood Prince,
# Relevancia: 0.830
# Reseña: Harry Potter grows up. Harry Potter needs to shave. Harry Potter shows more interest in the young ladies at Hogwarts.
#
# =====================================================================================================================
#
# Película: Harry Potter and the Prisoner of Azkaban,
# Relevancia: 0.820
# Reseña: Not only is this the best Harry Potter movie, it is the first Harry Potter movie that actually qualifies as cinema.
#
# =====================================================================================================================
#
# Película: Doctor Strange,
# Relevancia: 0.804
# Reseña: The movie is very much Harry Potter for adults.
#
# =====================================================================================================================
#
# Película: Harry Potter and the Half-Blood Prince,
# Relevancia: 0.802
# Reseña: Harry Potter and the Half-Blood Prince might be the best Harry Potter film yet.
#
# =====================================================================================================================
#
# Película: Harry Potter and the Order of the Phoenix,
# Relevancia: 0.801
# Reseña: The second best Harry Potter movie.
#
# =====================================================================================================================
#
# Película: Harry Potter and the Prisoner of Azkaban,
# Relevancia: 0.788
# Reseña: This is the best Harry Potter film to date.
#
# =====================================================================================================================
#
# Película: Harry Potter and the Goblet of Fire,
# Relevancia: 0.783
# Reseña: The best Harry Potter picture yet.
#
# =====================================================================================================================
#
# Película: The Lord of the Rings: The Fellowship of the Ring,
# Relevancia: 0.776
# Reseña: You think Harry Potter had expectations?
#
# =====================================================================================================================
#
# Película: Harry Potter and the Half-Blood Prince,
# Relevancia: 0.773
# Reseña: "Harry Potter and the Half-Blood Prince" is the most balanced Harry Potter film to come along...
#
# =====================================================================================================================
#
# Película: Harry Potter and the Prisoner of Azkaban,
# Relevancia: 0.770
# Reseña: All hail Harry Potter!
#
# =====================================================================================================================
#
# Película: Harry Potter and the Prisoner of Azkaban,
# Relevancia: 0.768
# Reseña: This time, Harry Potter is in a movie, "Harry Potter and the Prisoner of Azkaban," not just a translation of a novel.
#
# =====================================================================================================================
#
# Película: Harry Potter and the Goblet of Fire,
# Relevancia: 0.764
# Reseña: Harry Potter and the Goblet of Fire is yet another solid entry into the Harry Potter franchise.
#
# =====================================================================================================================
#
# Película: Harry Potter and the Half-Blood Prince,
# Relevancia: 0.760
# Reseña: Mostly I love Harry Potter for the actors
#
# =====================================================================================================================
#
# Película: Cirque du Freak: The Vampire's Assistant,
# Relevancia: 0.754
# Reseña: Harry Potter this ain't. But it's fun all the same.
#
# =====================================================================================================================
#
# Película: Harry Potter and the Goblet of Fire,
# Relevancia: 0.745
# Reseña: Easily the best Harry Potter film so far.
#
# =====================================================================================================================
#
# Película: Harry Potter and the Half-Blood Prince,
# Relevancia: 0.736
# Reseña: This is absolutely the best of the Harry Potter films so far.
#
# =====================================================================================================================
#
# Película: Harry Potter and the Deathly Hallows - Part 2,
# Relevancia: 0.735
# Reseña: Harry Potter, yeah, it's not bad.
#
# =====================================================================================================================
#
# Película: Harry Potter and the Half-Blood Prince,
# Relevancia: 0.734
# Reseña: Is there a more consistent franchise than Harry Potter?
#
# =====================================================================================================================
#
# Película: Kingsman: The Secret Service,
# Relevancia: 0.728
# Reseña: It's basically Harry Potter with spies.
#
# =====================================================================================================================
#
# Película: Harry Potter and the Goblet of Fire,
# Relevancia: 0.727
# Reseña: I think this is the best Potter film yet, for one simple reason: it's not like a Harry Potter film.
#
# =====================================================================================================================

# %% [markdown]
# rotten_tomatoes_link,movie_title,movie_info,critics_consensus,content_rating,genres,directors,authors,actors,original_release_date,streaming_release_date,runtime,production_company,tomatometer_status,tomatometer_rating,tomatometer_count,audience_status,audience_rating,audience_count,tomatometer_top_critics_count,tomatometer_fresh_critics_count,tomatometer_rotten_crit
